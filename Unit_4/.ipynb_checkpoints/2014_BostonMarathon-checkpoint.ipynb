# %% [markdown]
# ## Boston Marathon Data:

# %% [markdown]
# ### Importing and Cleaning:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('2014BostonMarathon.csv')

# %% [markdown]
# #### Null values:

# %%
# Looking at null-values:

df.isna().sum()
starting_df_length = len(df)

# %%
# Dropping 'Citizenship' since we already have a very similar column with Country.

df.drop('ctz', axis = 1, inplace = True)

# Since 'City' only had one null value, we will drop that row as well since it will be relatively inconsequential,
# and since it will allow us to nip any null-value issues in the bud at the start.

df.dropna(axis = 0, how = 'any', subset = ['city'], inplace = True)

# %% [markdown]
# #### Dash Control:

# %%
# Had to take care of some dashes within the dataset ('-'), which were making it difficult to run models.  
# Did not want to drop these since that would cause a lot of information loss

import re

df['5k'] = df['5k'].replace(to_replace = '-', value = np.nan)
df['10k'] = df['10k'].replace(to_replace = '-', value = np.nan)
df['20k'] = df['20k'].replace(to_replace = '-', value = np.nan)
df['25k'] = df['25k'].replace(to_replace = '-', value = np.nan)
df['30k'] = df['30k'].replace(to_replace = '-', value = np.nan)
df['35k'] = df['35k'].replace(to_replace = '-', value = np.nan)
df['40k'] = df['40k'].replace(to_replace = '-', value = np.nan)
df['half'] = df['half'].replace(to_replace = '-', value = np.nan)

# %% [markdown]
# #### Dummy Control:

# %%
# Had to do some grouping to control dummies:
EUR = ['TUR', 'HUN', 'LUX', 'UKR', 'BLR', 'CRO', 'EST', 'SVK', 'SLO', 'POR', 'GRE', 'CZE', 'ROU', 'LIE',
       'POL', 'AUT', 'NOR', 'BEL', 'FIN', 'ISL']
df['country'] = df['country'].where(df['country'].apply(lambda x: x not in EUR), other = 'EUR')

SEA = ['PHI', 'THA', 'MAS', 'INA', 'NZL']
df['country'] = df['country'].where(df['country'].apply(lambda x: x not in SEA), other = 'SEA')

AFR = ['EGY', 'ZIM', 'TAN', 'ETH', 'MAR', 'KEN', 'RSA']
df['country'] = df['country'].where(df['country'].apply(lambda x: x not in AFR), other = 'AFR')

CAM = ['PAN', 'DOM', 'BAH', 'CAY', 'VGB', 'BAR', 'ESA', 'GUA', 'CRC', 'BER']
df['country'] = df['country'].where(df['country'].apply(lambda x: x not in CAM), other = 'CAM')

SAM = ['ECU', 'BOL', 'TRI', 'PER', 'URU', 'ARG', 'CHI', 'VEN']
df['country'] = df['country'].where(df['country'].apply(lambda x: x not in SAM), other = 'SAM')

MEA = ['QAT', 'BRN', 'ISR', 'UAE']
df['country'] = df['country'].where(df['country'].apply(lambda x: x not in MEA), other = 'MEA')

ASI = ['IND', 'RUS', 'TPE', 'SIN']
df['country'] = df['country'].where(df['country'].apply(lambda x: x not in ASI), other = 'ASI')

# %% [markdown]
# #### Misc:

# %%
# Was getting an NaN, Inf, Value Too Large error when running the preliminary models. So: 

df['pace'] = pd.to_numeric(df['pace'], downcast = 'float')
df['official'] = pd.to_numeric(df['official'], downcast = 'float')

# %% [markdown]
# ### Preliminary Exploration (Understanding the Structure and Distrubution):

# %%
pd.set_option('max_columns', 22)
df.describe(include = 'all')
# Out:
#           10k          name      division     25k gender           age  \
# count   31933         31983  31983.000000   31767  31983  31983.000000
# unique   2765         31914           NaN    6569      2           NaN
# top     48.38  Burns, Karen           NaN  123.30      M           NaN
# freq       47             2           NaN      25  17617           NaN
# mean      NaN           NaN   1932.615858     NaN    NaN     42.406716
# std       NaN           NaN   1715.229489     NaN    NaN     11.316488
# min       NaN           NaN      1.000000     NaN    NaN     18.000000
# 25%       NaN           NaN    610.000000     NaN    NaN     33.000000
# 50%       NaN           NaN   1425.000000     NaN    NaN     42.000000
# 75%       NaN           NaN   2611.000000     NaN    NaN     50.000000
# max       NaN           NaN   6979.000000     NaN    NaN     81.000000
#
#             official    bib     genderdiv     35k       overall          pace  \
# count   31983.000000  31983  31983.000000   31949  31983.000000  31983.000000
# unique           NaN  31983           NaN    9515           NaN           NaN
# top              NaN  27927           NaN  186.28           NaN           NaN
# freq             NaN      1           NaN      17           NaN           NaN
# mean      242.997849    NaN   8051.148579     NaN  15939.640340      9.275678
# std        52.301167    NaN   4754.043678     NaN   9233.117792      1.992514
# min        80.599998    NaN      1.000000     NaN      1.000000      3.080000
# 25%       205.525002    NaN   3972.000000     NaN   7943.500000      7.850000
# 50%       232.369995    NaN   7970.000000     NaN  15940.000000      8.870000
# 75%       273.240005    NaN  11968.000000     NaN  23935.500000     10.430000
# max       538.880005    NaN  17575.000000     NaN  31931.000000     20.570000
#
#         state     30k     5k    half    20k country    city     40k
# count   29408   31943  31931   31911  31932   31983   31983   31944
# unique     68    8089   1490    5650   5374      27    5934   10545
# top        MA  146.32  23.93  101.98  99.33     USA  Boston  205.60
# freq     7587      19     81      27     28   27233    1034      16
# mean      NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# std       NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# min       NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 25%       NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 50%       NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 75%       NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN
# max       NaN     NaN    NaN     NaN    NaN     NaN     NaN     NaN

# %% [markdown]
# ### Preliminary Visualizations:

# %%
plt.figure(figsize = (9, 7))
sns.heatmap(df.corr(), annot = True)
plt.show()

# %% [markdown]
# ### Using GridSearchCV to run some preliminary models:

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest

df.dropna(axis = 1, how = 'any')
end_df_len = len(df)

X = pd.get_dummies(data = df.drop(['name', 'bib', 'city', 'state', 'genderdiv'], axis = 1), columns = ['gender', 'country'])
y = df['genderdiv']

# %%
SKB_genderdiv = SelectKBest(k = 7)
SKB_genderdiv_PCA = SKB_genderdiv.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-8f431ebf5688> in <module>
#       1 SKB_genderdiv = SelectKBest(k = 7)
# ----> 2 SKB_genderdiv_PCA = SKB_genderdiv.fit(X, y)
#
# /usr/local/lib/python3.7/site-packages/sklearn/feature_selection/univariate_selection.py in fit(self, X, y)
#     338         self : object
#     339         """
# --> 340         X, y = check_X_y(X, y, ['csr', 'csc'], multi_output=True)
#     341
#     342         if not callable(self.score_func):
#
# /usr/local/lib/python3.7/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     740                     ensure_min_features=ensure_min_features,
#     741                     warn_on_dtype=warn_on_dtype,
# --> 742                     estimator=estimator)
#     743     if multi_output:
#     744         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /usr/local/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     561         if force_all_finite:
#     562             _assert_all_finite(array,
# --> 563                                allow_nan=force_all_finite == 'allow-nan')
#     564
#     565     shape_repr = _shape_repr(array.shape)
#
# /usr/local/lib/python3.7/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan)
#      54                 not allow_nan and not np.isfinite(X).all()):
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57
#      58
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
df
# Out:
#          10k                        name  division     25k gender  age  \
# 0      17.37          Yamamoto, Hiroyuki         8   47.67      M   47
# 1      32.58                Jeptoo, Rita         1   82.43      F   33
# 2      16.62           Van Dyk, Ernst F.         1   45.80      M   41
# 3      32.57                Dibaba, Mare         3   82.43      F   24
# 4      17.12              Hokinoue, Kota         2   46.37      M   40
# 5      32.58     Sumgong, Jemima Jelagat         4   82.45      F   29
# 6      17.65              Hug, Marcel E.         4   47.67      M   28
# 7      30.48              Geneti, Markos         5   76.95      M   29
# 8      17.12           Soejima, Masazumi         3   46.37      M   43
# 9      30.48                  Hall, Ryan        20   77.68      M   31
# 10     32.58              Cherop, Sharon         8   82.45      F   30
# 11     30.52              Chebet, Wilson         2   76.97      M   28
# 12     18.13        Lemeunier, Denis Sr.        11   49.17      M   49
# 13     32.58             Kilel, Caroline        17   85.55      F   33
# 14     17.12            Cassidy, Josh R.        13   48.88      M   29
# 15     33.93             Linden, Desiree        10   85.03      F   30
# 16     17.13               Madera, Jordi         5   47.45      M   34
# 17     32.57              Deba, Buzunesh         2   82.43      F   26
# 18     18.17            Hamerlak, Tomasz         7   49.15      M   38
# 19     34.80  Petrova Arkhipova, Tatiana        13   87.83      F   31
# 20     30.50        Chepkwony, Frankline         3   76.95      M   29
# 21     33.23          Duliba, Aleksandra         6   83.40      F   26
# 22     30.50                 Kogo, Micah        17   76.97      M   27
# 23     18.17     Botello Jimenez, Rafael        12   49.15      M   35
# 24     18.30             Filteau, Michel        14   50.33      M   47
# 25     33.02              Esayias, Yeshi        12   85.03      F   28
# 26     30.53                Annani, Adil        10   76.97      M   33
# 27     18.78                Kim, Gyu Dae        15   50.33      M   30
# 28     33.02              Ongori, Philes         9   83.43      F   27
# 29     30.52            Lonyangata, Paul         9   76.97      M   31
# ...      ...                         ...       ...     ...    ...  ...
# 31954  57.83                Young, Brian      4242  141.17      M   30
# 31955  67.77             Masiiwa, Graham      5072  174.53      M   35
# 31956  55.52           Damour, Justin N.      4818  143.80      M   37
# 31957  56.35             Bobel, Emily C.      4377  140.80      F   32
# 31958  72.95        Orlando, Christopher      1740  193.82      M   58
# 31959  68.58            Nugent, Emily J.      6008  176.93      F   24
# 31960  59.25          Svendsen, Lance A.      5087  157.38      M   29
# 31961  72.07           Bitton, Elizabeth      6787  204.37      F   37
# 31962  72.07     Raisner Thompson, Debra      2249  204.37      F   47
# 31963  49.38              Ginsberg, Rick      1939  125.35      M   43
# 31964  57.20          Shanley, Seamus P.      4432  147.32      M   36
# 31965  73.15       Aldenberg, William B.      2818  187.78      M   45
# 31966  68.95        Tamuleviz, Joseph G.      2434  198.90      M   54
# 31967  57.80             Page, Janice C.       910  148.15      F   52
# 31968  77.03             Quinn, Alexa K.      6742  208.68      F   23
# 31969  63.62      O'Donnell, Jennifer R.      6501  169.60      F   18
# 31970  57.75           Maggiacomo, Derek      2187  149.88      M   44
# 31971  67.67        Pearless, Kristen E.      2203  190.55      F   43
# 31972  68.18             Donahoe, Daniel      5604  188.33      M   31
# 31973  69.53              Reno, James T.      1725  190.55      M   56
# 31974  76.45            Foley, Alison M.      6973     NaN      F   29
# 31975  75.80       Casey, Patrick A. Jr.      2897     NaN      M   45
# 31976  63.95          Lyons, Paul J. Jr.      4993  161.75      M   33
# 31977  63.33        Vinal, George R. Jr.      5217  165.40      M   37
# 31978  76.75               Morris, David      2598  210.07      M   44
# 31979  50.72          Anderson, Steve K.      3414  124.02      M   32
# 31980  61.28        McCarthy, Michael P.      5212  165.02      M   34
# 31981  59.00           Brimmer, Delia C.      5231  157.02      F   21
# 31982  63.75             Morganthal, Amy      5800  167.82      F   38
# 31983  53.63        Kirchner, Jeffrey T.      1396  135.02      M   54
#
#          official    bib  genderdiv     35k  overall   pace state     30k  \
# 0       85.250000     W1          8   71.40        8   3.27   NaN   59.18
# 1      138.949997     F1          1  116.37       21   5.30   NaN   99.33
# 2       80.599998     W2          1   67.42        1   3.08   NaN   56.45
# 3      140.580002     F2          3  116.37       27   5.37   NaN   99.33
# 4       81.230003     W3          2   67.83        2   3.10   NaN   57.03
# 5      140.679993     F3          4  116.37       28   5.37   NaN   99.33
# 6       84.650002     W4          4   70.23        4   3.23   NaN   58.60
# 7      129.830002      5          5  107.47        5   4.97   NaN   92.52
# 8       81.230003     W6          3   67.83        3   3.10   NaN   57.03
# 9      137.830002      6         20  112.27       20   5.27    CA   94.78
# 10     143.000000     F6          8  116.92       40   5.47   NaN   99.35
# 11     128.800003      7          2  107.47        2   4.92   NaN   92.52
# 12      86.949997     W7         11   72.60       11   3.32   NaN   60.85
# 13     152.070007     F7         17  124.22      121   5.80   NaN  104.62
# 14      87.400002     W8         13   72.83       13   3.35    ON   60.82
# 15     143.899994     F8         10  119.68       46   5.50    MI  102.40
# 16      84.699997     W9          5   70.60        5   3.23   NaN   58.73
# 17     139.979996    F10          2  116.38       25   5.35   NaN   99.35
# 18      84.879997    W10          7   70.83        7   3.25   NaN   59.92
# 19     150.479996    F11         13  124.53      102   5.75   NaN  106.03
# 20     128.830002     11          3  107.47        3   4.92   NaN   92.52
# 21     141.479996    F12          6  117.65       34   5.40   NaN  100.58
# 22     137.199997     12         17  109.12       17   5.23   NaN   92.52
# 23      86.949997    W12         12   72.70       12   3.32   NaN   60.87
# 24      89.400002    W13         14   74.95       14   3.42    QC   62.33
# 25     147.669998    F14         12  121.60       71   5.63   NaN  102.92
# 26     132.720001     14         10  109.15       10   5.07   NaN   92.60
# 27      89.519997    W14         15   75.02       15   3.42    IL   62.72
