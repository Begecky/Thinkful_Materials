# %% [markdown]
# ## Boston Marathon Data:

# %% [markdown]
# ### Importing and Cleaning:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('2014BostonMarathon.csv')

# %% [markdown]
# ### Preliminary Exploration (Understanding the Structure and Distrubution):

# %%
pd.set_option('max_columns', 22)
df.describe(include = 'all')
# Out:
#           10k           name      division    25k gender           age  \
# count   31984          31984  31984.000000  31984  31984  31984.000000
# unique   2766          31915           NaN   6570      2           NaN
# top         -  Baynes, Chris           NaN      -      M           NaN
# freq       50              2           NaN    216  17617           NaN
# mean      NaN            NaN   1932.563032    NaN    NaN     42.407079
# std       NaN            NaN   1715.228694    NaN    NaN     11.316496
# min       NaN            NaN      1.000000    NaN    NaN     18.000000
# 25%       NaN            NaN    610.000000    NaN    NaN     33.000000
# 50%       NaN            NaN   1425.000000    NaN    NaN     42.000000
# 75%       NaN            NaN   2611.000000    NaN    NaN     50.000000
# max       NaN            NaN   6979.000000    NaN    NaN     81.000000
#
#             official    bib     genderdiv   ctz    35k       overall  \
# count   31984.000000  31984  31984.000000  1244  31984  31984.000000
# unique           NaN  31984           NaN    84   9516           NaN
# top              NaN   5367           NaN   GBR      -           NaN
# freq             NaN      1           NaN   171     34           NaN
# mean      242.997314    NaN   8051.044741   NaN    NaN  15939.587825
# std        52.300431    NaN   4754.005626   NaN    NaN   9232.978224
# min        80.600000    NaN      1.000000   NaN    NaN      1.000000
# 25%       205.527500    NaN   3972.000000   NaN    NaN   7943.750000
# 50%       232.370000    NaN   7970.000000   NaN    NaN  15939.500000
# 75%       273.235000    NaN  11968.000000   NaN    NaN  23935.250000
# max       538.880000    NaN  17575.000000   NaN    NaN  31931.000000
#
#                 pace  state    30k     5k   half    20k country    city    40k
# count   31984.000000  29408  31984  31984  31984  31984   31984   31983  31984
# unique           NaN     68   8090   1491   5651   5375      78    5934  10546
# top              NaN     MA      -  23.93      -      -     USA  Boston      -
# freq             NaN   7587     40     81     72     51   27233    1034     39
# mean        9.275658    NaN    NaN    NaN    NaN    NaN     NaN     NaN    NaN
# std         1.992486    NaN    NaN    NaN    NaN    NaN     NaN     NaN    NaN
# min         3.080000    NaN    NaN    NaN    NaN    NaN     NaN     NaN    NaN
# 25%         7.850000    NaN    NaN    NaN    NaN    NaN     NaN     NaN    NaN
# 50%         8.870000    NaN    NaN    NaN    NaN    NaN     NaN     NaN    NaN
# 75%        10.430000    NaN    NaN    NaN    NaN    NaN     NaN     NaN    NaN
# max        20.570000    NaN    NaN    NaN    NaN    NaN     NaN     NaN    NaN

# %%
# Looking at null-values:

df.isna().sum()
# Out:
# 10k              0
# name             0
# division         0
# 25k              0
# gender           0
# age              0
# official         0
# bib              0
# genderdiv        0
# ctz          30740
# 35k              0
# overall          0
# pace             0
# state         2576
# 30k              0
# 5k               0
# half             0
# 20k              0
# country          0
# city             1
# 40k              0
# dtype: int64

# %%
# Dropping 'Citizenship' since we already have a very similar column with Country.

df.drop('ctz', axis = 1, inplace = True)

# Since 'City' only had one null value, we will drop that row as well since it will be relatively inconsequential,
# and since it will allow us to nip any null-value issues in the bud at the start.

df.dropna(axis = 0, how = 'any', subset = ['city'], inplace = True)

# %%
df.isna().sum()
# Out:
# 10k             0
# name            0
# division        0
# 25k             0
# gender          0
# age             0
# official        0
# bib             0
# genderdiv       0
# 35k             0
# overall         0
# pace            0
# state        2575
# 30k             0
# 5k              0
# half            0
# 20k             0
# country         0
# city            0
# 40k             0
# dtype: int64

# %% [markdown]
# ### Preliminary Visualizations:

# %%
plt.figure(figsize = (9, 7))
sns.heatmap(df.corr(), annot = True)
plt.show()

# %%
# pd.to_numeric(df['20k'], errors = 'ignore')

# %%
dash_cols = df[['10k', '25k', '5k', '35k', '30k', '20k', '40k']]
dash_cols.where((dash_cols != '-'), other = np.nan)

df.drop(labels = ['10k', '25k', '5k', '35k', '30k', '20k', '40k'], axis = 1)
dash_cols.join(df, on = dash_cols.index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-160-deb78ad50c35> in <module>
#       3
#       4 df.drop(labels = ['10k', '25k', '5k', '35k', '30k', '20k', '40k'], axis = 1)
# ----> 5 dash_cols.join(df, on = dash_cols.index)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    6334         # For SparseDataFrame's benefit
#    6335         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 6336                                  rsuffix=rsuffix, sort=sort)
#    6337
#    6338     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    6349             return merge(self, other, left_on=on, how=how,
#    6350                          left_index=on is None, right_index=True,
# -> 6351                          suffixes=(lsuffix, rsuffix), sort=sort)
#    6352         else:
#    6353             if on is not None:
#
# /usr/local/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      60                          copy=copy, indicator=indicator,
#      61                          validate=validate)
# ---> 62     return op.get_result()
#      63
#      64
#
# /usr/local/lib/python3.7/site-packages/pandas/core/reshape/merge.py in get_result(self)
#     572
#     573         llabels, rlabels = items_overlap_with_suffix(ldata.items, lsuf,
# --> 574                                                      rdata.items, rsuf)
#     575
#     576         lindexers = {1: left_indexer} if left_indexer is not None else {}
#
# /usr/local/lib/python3.7/site-packages/pandas/core/internals.py in items_overlap_with_suffix(left, lsuffix, right, rsuffix)
#    5242         if not lsuffix and not rsuffix:
#    5243             raise ValueError('columns overlap but no suffix specified: '
# -> 5244                              '{rename}'.format(rename=to_rename))
#    5245
#    5246         def lrenamer(x):
#
# ValueError: columns overlap but no suffix specified: Index(['10k', '25k', '5k', '35k', '30k', '20k', '40k'], dtype='object')

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest

X = df.drop(['state', 'genderdiv'], axis = 1)
y = df['genderdiv']

SKB_genderdiv = SelectKBest(k = 7)
SKB_gd_features = SKB_genderdiv.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-147-88c37e62bd21> in <module>
#       7
#       8 SKB_genderdiv = SelectKBest(k = 7)
# ----> 9 SKB_gd_features = SKB_genderdiv.fit(X, y)
#
# /usr/local/lib/python3.7/site-packages/sklearn/feature_selection/univariate_selection.py in fit(self, X, y)
#     338         self : object
#     339         """
# --> 340         X, y = check_X_y(X, y, ['csr', 'csc'], multi_output=True)
#     341
#     342         if not callable(self.score_func):
#
# /usr/local/lib/python3.7/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     740                     ensure_min_features=ensure_min_features,
#     741                     warn_on_dtype=warn_on_dtype,
# --> 742                     estimator=estimator)
#     743     if multi_output:
#     744         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /usr/local/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     555         # make sure we actually converted to numeric:
#     556         if dtype_numeric and array.dtype.kind == "O":
# --> 557             array = array.astype(np.float64)
#     558         if not allow_nd and array.ndim >= 3:
#     559             raise ValueError("Found array with dim %d. %s expected <= 2."
#
# ValueError: could not convert string to float: '-'

# %%
# X_train, X_test, y_train, y_test = train_test_split()
