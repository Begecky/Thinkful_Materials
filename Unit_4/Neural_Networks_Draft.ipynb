# %%
import pandas as pd
import numpy as np
import gc
pd.set_option('display.max_rows', 400)

# %%
col_list = ['GenderSelect', 'Country', 'Age', 'EmploymentStatus', 'StudentStatus', 'LearningDataScience', 
            'CodeWriter', 'CareerSwitcher', 'CurrentEmployerType', 'MLToolNextYearSelect', 'MLMethodNextYearSelect',
            'LanguageRecommendationSelect', 'PublicDatasetsSelect', 'BlogsPodcastsNewslettersSelect', 'LearningDataScienceTime', 'JobSkillImportanceBigData', 
            'JobSkillImportanceDegree', 'JobSkillImportanceStats', 'JobSkillImportanceEnterpriseTools', 
            'JobSkillImportancePython', 'JobSkillImportanceR', 'JobSkillImportanceSQL', 'JobSkillImportanceKaggleRanking',
            'JobSkillImportanceMOOC', 'JobSkillImportanceVisualizations', 'ProveKnowledgeSelect', 'FormalEducation', 
            'MajorSelect', 'Tenure', 'PastJobTitlesSelect', 'FirstTrainingSelect', 'LearningCategorySelftTaught', 
            'LearningCategoryOnlineCourses', 'LearningCategoryWork', 'LearningCategoryUniversity', 'LearningCategoryKaggle', 
            'LearningCategoryOther', 'MLSkillsSelect', 'MLTechniquesSelect', 'JobHuntTime']

df = pd.read_csv('Kaggle_Survey.csv', encoding = 'latin-1')
# Out:
# /usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3018: DtypeWarning: Columns (31,83,86,87,98,99,109,116,123,124,127,129,130,164) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
info = pd.DataFrame()
info['type'] = df.dtypes
info['col_num'] = np.arange(0, 228, 1)

# %%
info
# Out:
#                                                 type  col_num
# GenderSelect                                  object        0
# Country                                       object        1
# Age                                          float64        2
# EmploymentStatus                              object        3
# StudentStatus                                 object        4
# LearningDataScience                           object        5
# CodeWriter                                    object        6
# CareerSwitcher                                object        7
# CurrentJobTitleSelect                         object        8
# TitleFit                                      object        9
# CurrentEmployerType                           object       10
# MLToolNextYearSelect                          object       11
# MLMethodNextYearSelect                        object       12
# LanguageRecommendationSelect                  object       13
# PublicDatasetsSelect                          object       14
# LearningPlatformSelect                        object       15
# LearningPlatformUsefulnessArxiv               object       16
# LearningPlatformUsefulnessBlogs               object       17
# LearningPlatformUsefulnessCollege             object       18
# LearningPlatformUsefulnessCompany             object       19
# LearningPlatformUsefulnessConferences         object       20
# LearningPlatformUsefulnessFriends             object       21
# LearningPlatformUsefulnessKaggle              object       22
# LearningPlatformUsefulnessNewsletters         object       23
# LearningPlatformUsefulnessCommunities         object       24
# LearningPlatformUsefulnessDocumentation       object       25
# LearningPlatformUsefulnessCourses             object       26
# LearningPlatformUsefulnessProjects            object       27
# LearningPlatformUsefulnessPodcasts            object       28
# LearningPlatformUsefulnessSO                  object       29
# LearningPlatformUsefulnessTextbook            object       30
# LearningPlatformUsefulnessTradeBook           object       31
# LearningPlatformUsefulnessTutoring            object       32
# LearningPlatformUsefulnessYouTube             object       33
# BlogsPodcastsNewslettersSelect                object       34
# LearningDataScienceTime                       object       35
# JobSkillImportanceBigData                     object       36
# JobSkillImportanceDegree                      object       37
# JobSkillImportanceStats                       object       38
# JobSkillImportanceEnterpriseTools             object       39
# JobSkillImportancePython                      object       40
# JobSkillImportanceR                           object       41
# JobSkillImportanceSQL                         object       42
# JobSkillImportanceKaggleRanking               object       43
# JobSkillImportanceMOOC                        object       44
# JobSkillImportanceVisualizations              object       45
# JobSkillImportanceOtherSelect1                object       46
# JobSkillImportanceOtherSelect2                object       47
# JobSkillImportanceOtherSelect3                object       48
# CoursePlatformSelect                          object       49
# HardwarePersonalProjectsSelect                object       50
# TimeSpentStudying                             object       51
# ProveKnowledgeSelect                          object       52
# DataScienceIdentitySelect                     object       53
# FormalEducation                               object       54
# MajorSelect                                   object       55
# Tenure                                        object       56
# PastJobTitlesSelect                           object       57
# FirstTrainingSelect                           object       58
# LearningCategorySelftTaught                  float64       59
# LearningCategoryOnlineCourses                float64       60
# LearningCategoryWork                         float64       61
# LearningCategoryUniversity                   float64       62
# LearningCategoryKaggle                       float64       63
# LearningCategoryOther                        float64       64
# MLSkillsSelect                                object       65
# MLTechniquesSelect                            object       66
# ParentsEducation                              object       67
# EmployerIndustry                              object       68
# EmployerSize                                  object       69
# EmployerSizeChange                            object       70
# EmployerMLTime                                object       71
# EmployerSearchMethod                          object       72
# UniversityImportance                          object       73
# JobFunctionSelect                             object       74
# WorkHardwareSelect                            object       75
# WorkDataTypeSelect                            object       76
# WorkProductionFrequency                       object       77
# WorkDatasetSize                               object       78
# WorkAlgorithmsSelect                          object       79
# WorkToolsSelect                               object       80
# WorkToolsFrequencyAmazonML                    object       81
# WorkToolsFrequencyAWS                         object       82
# WorkToolsFrequencyAngoss                      object       83
# WorkToolsFrequencyC                           object       84
# WorkToolsFrequencyCloudera                    object       85
# WorkToolsFrequencyDataRobot                   object       86
# WorkToolsFrequencyFlume                       object       87
# WorkToolsFrequencyGCP                         object       88
# WorkToolsFrequencyHadoop                      object       89
# WorkToolsFrequencyIBMCognos                   object       90
# WorkToolsFrequencyIBMSPSSModeler              object       91
# WorkToolsFrequencyIBMSPSSStatistics           object       92
# WorkToolsFrequencyIBMWatson                   object       93
# WorkToolsFrequencyImpala                      object       94
# WorkToolsFrequencyJava                        object       95
# WorkToolsFrequencyJulia                       object       96
# WorkToolsFrequencyJupyter                     object       97
# WorkToolsFrequencyKNIMECommercial             object       98
# WorkToolsFrequencyKNIMEFree                   object       99
# WorkToolsFrequencyMathematica                 object      100
# WorkToolsFrequencyMATLAB                      object      101
# WorkToolsFrequencyAzure                       object      102
# WorkToolsFrequencyExcel                       object      103
# WorkToolsFrequencyMicrosoftRServer            object      104
# WorkToolsFrequencyMicrosoftSQL                object      105
# WorkToolsFrequencyMinitab                     object      106
# WorkToolsFrequencyNoSQL                       object      107
# WorkToolsFrequencyOracle                      object      108
# WorkToolsFrequencyOrange                      object      109
# WorkToolsFrequencyPerl                        object      110
# WorkToolsFrequencyPython                      object      111
# WorkToolsFrequencyQlik                        object      112
# WorkToolsFrequencyR                           object      113
# WorkToolsFrequencyRapidMinerCommercial        object      114
# WorkToolsFrequencyRapidMinerFree              object      115
# WorkToolsFrequencySalfrod                     object      116
# WorkToolsFrequencySAPBusinessObjects          object      117
# WorkToolsFrequencySASBase                     object      118
# WorkToolsFrequencySASEnterprise               object      119
# WorkToolsFrequencySASJMP                      object      120
# WorkToolsFrequencySpark                       object      121
# WorkToolsFrequencySQL                         object      122
# WorkToolsFrequencyStan                        object      123
# WorkToolsFrequencyStatistica                  object      124
# WorkToolsFrequencyTableau                     object      125
# WorkToolsFrequencyTensorFlow                  object      126
# WorkToolsFrequencyTIBCO                       object      127
# WorkToolsFrequencyUnix                        object      128
# WorkToolsFrequencySelect1                     object      129
# WorkToolsFrequencySelect2                     object      130
# WorkFrequencySelect3                          object      131
# WorkMethodsSelect                             object      132
# WorkMethodsFrequencyA/B                       object      133
# WorkMethodsFrequencyAssociationRules          object      134
# WorkMethodsFrequencyBayesian                  object      135
# WorkMethodsFrequencyCNNs                      object      136
# WorkMethodsFrequencyCollaborativeFiltering    object      137
# WorkMethodsFrequencyCross-Validation          object      138
# WorkMethodsFrequencyDataVisualization         object      139
# WorkMethodsFrequencyDecisionTrees             object      140
# WorkMethodsFrequencyEnsembleMethods           object      141
# WorkMethodsFrequencyEvolutionaryApproaches    object      142
# WorkMethodsFrequencyGANs                      object      143
# WorkMethodsFrequencyGBM                       object      144
# WorkMethodsFrequencyHMMs                      object      145
# WorkMethodsFrequencyKNN                       object      146
# WorkMethodsFrequencyLiftAnalysis              object      147
# WorkMethodsFrequencyLogisticRegression        object      148
# WorkMethodsFrequencyMLN                       object      149
# WorkMethodsFrequencyNaiveBayes                object      150
# WorkMethodsFrequencyNLP                       object      151
# WorkMethodsFrequencyNeuralNetworks            object      152
# WorkMethodsFrequencyPCA                       object      153
# WorkMethodsFrequencyPrescriptiveModeling      object      154
# WorkMethodsFrequencyRandomForests             object      155
# WorkMethodsFrequencyRecommenderSystems        object      156
# WorkMethodsFrequencyRNNs                      object      157
# WorkMethodsFrequencySegmentation              object      158
# WorkMethodsFrequencySimulation                object      159
# WorkMethodsFrequencySVMs                      object      160
# WorkMethodsFrequencyTextAnalysis              object      161
# WorkMethodsFrequencyTimeSeriesAnalysis        object      162
# WorkMethodsFrequencySelect1                   object      163
# WorkMethodsFrequencySelect2                   object      164
# WorkMethodsFrequencySelect3                   object      165
# TimeGatheringData                            float64      166
# TimeModelBuilding                            float64      167
# TimeProduction                               float64      168
# TimeVisualizing                              float64      169
# TimeFindingInsights                          float64      170
# TimeOtherSelect                              float64      171
# AlgorithmUnderstandingLevel                   object      172
# WorkChallengesSelect                          object      173
# WorkChallengeFrequencyPolitics                object      174
# WorkChallengeFrequencyUnusedResults           object      175
# WorkChallengeFrequencyUnusefulInstrumenting   object      176
# WorkChallengeFrequencyDeployment              object      177
# WorkChallengeFrequencyDirtyData               object      178
# WorkChallengeFrequencyExplaining              object      179
# WorkChallengeFrequencyPass                    object      180
# WorkChallengeFrequencyIntegration             object      181
# WorkChallengeFrequencyTalent                  object      182
# WorkChallengeFrequencyDataFunds               object      183
# WorkChallengeFrequencyDomainExpertise         object      184
# WorkChallengeFrequencyML                      object      185
# WorkChallengeFrequencyTools                   object      186
# WorkChallengeFrequencyExpectations            object      187
# WorkChallengeFrequencyITCoordination          object      188
# WorkChallengeFrequencyHiringFunds             object      189
# WorkChallengeFrequencyPrivacy                 object      190
# WorkChallengeFrequencyScaling                 object      191
# WorkChallengeFrequencyEnvironments            object      192
# WorkChallengeFrequencyClarity                 object      193
# WorkChallengeFrequencyDataAccess              object      194
# WorkChallengeFrequencyOtherSelect             object      195
# WorkDataVisualizations                        object      196
# WorkInternalVsExternalTools                   object      197
# WorkMLTeamSeatSelect                          object      198
# WorkDatasets                                  object      199
# WorkDatasetsChallenge                         object      200
# WorkDataStorage                               object      201
# WorkDataSharing                               object      202
# WorkDataSourcing                              object      203
# WorkCodeSharing                               object      204
# RemoteWork                                    object      205
# CompensationAmount                            object      206
# CompensationCurrency                          object      207
# SalaryChange                                  object      208
# JobSatisfaction                               object      209
# JobSearchResource                             object      210
# JobHuntTime                                   object      211
# JobFactorLearning                             object      212
# JobFactorSalary                               object      213
# JobFactorOffice                               object      214
# JobFactorLanguages                            object      215
# JobFactorCommute                              object      216
# JobFactorManagement                           object      217
# JobFactorExperienceLevel                      object      218
# JobFactorDepartment                           object      219
# JobFactorTitle                                object      220
# JobFactorCompanyFunding                       object      221
# JobFactorImpact                               object      222
# JobFactorRemote                               object      223
# JobFactorIndustry                             object      224
# JobFactorLeaderReputation                     object      225
# JobFactorDiversity                            object      226
# JobFactorPublishingOpportunity                object      227
